# %% [markdown]
# <a href="https://colab.research.google.com/github/bhuvansai33/my-first-repo/blob/main/python_basics_%3CBhuvan_sai%3E.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Task 1: Variables and Data Types Create variables to store a person's name (string), age (integer), height in meters (float), and whether they are a student (boolean). Print all four values in a single print() statement.

# %%
# Task 1: Variables and Data Types
name = "Alex"           # string
age = 25                # integer
height = 1.75           # float
is_student = True       # boolean
# Out:
# Alex 25 1.75 True

# %% [markdown]
# Task 2: String Formatting Using the variables from Task 1, print a sentence in the following format: Name: <name> | Age: <age> | Height: <height> | Student: <is_student>

# %%
# Task 2: String Formatting
# Using f-string for the specified format
print(f"Name: {name} | Age: {age} | Height: {height} | Student: {is_student}")
# Out:
# Name: Alex | Age: 25 | Height: 1.75 | Student: True

# %% [markdown]
# Task 3: Arithmetic Operations Using the age variable, calculate and print:
#
# 1.Age in months
# 2.Age in days (assume 365 days/year)
# 3.The remainder when age is divided by 7
# 4.Age raised to the power of 2

# %%
# Task 3: Arithmetic Operations
age_in_months = age * 12
age_in_days = age * 365
remainder_age = age % 7
age_squared = age ** 2

print(age_in_months)
print(age_in_days)
print(remainder_age)
print(age_squared)
# Out:
# 300
# 9125
# 4
# 625
